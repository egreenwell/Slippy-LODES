# %%
from pygris import tracts
from pygris.data import get_lodes
from pyproj import CRS
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs
import mapclassify as mc
from shapely.geometry import Point
from shapely.geometry import MultiPoint
import folium
import geojson
import requests

# %%
#step 1 get lodes
va_lodes_od = get_lodes(
    state = "VA",
    year = 2021,
    lodes_type = "od")

va_lodes_od.head()
# Out:
#    index        w_geocode        h_geocode  S000  SA01  SA02  SA03  SE01  \
# 0      0  510010901011006  510010902023010     1     0     1     0     1
# 1      1  510010901011011  510010901011027     1     0     1     0     0
# 2      2  510010901011011  510010901011033     1     0     0     1     0
# 3      3  510010901011011  510010901011041     1     1     0     0     1
# 4      4  510010901011011  510010901021002     1     0     0     1     0
#
#    SE02  SE03  SI01  SI02  SI03
# 0     0     0     0     0     1
# 1     1     0     1     0     0
# 2     1     0     0     1     0
# 3     0     0     0     1     0
# 4     1     0     0     1     0

# %%
#first testing people who commute TO tracts in Charles city
TO_charles_city = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("510366")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_charles_city.head()

# %%
TO_charles_city.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_Charles_City.xlsx', index=False)

# %%
#Now for the rest of the Region - 
FROM_charles_city = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("510366")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

FROM_charles_city.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_Charles_City.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\3045886226.py:8: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})

# %%
TO_chesterfield = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("510411")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

FROM_chesterfield = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("510411")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_chesterfield.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_Chesterfield.xlsx', index=False)
FROM_chesterfield.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_Chesterfield.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2143103533.py:7: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2143103533.py:17: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})

# %%
TO_goochland = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("510754")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)
FROM_goochland = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("510754")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_goochland.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_Goochland.xlsx', index=False)
FROM_goochland.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_Goochland.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\3820006206.py:7: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\3820006206.py:16: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})

# %%
TO_hanover = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("510853")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)
FROM_hanover = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("510853")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_hanover.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_Hanover.xlsx', index=False)
FROM_hanover.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_Hanover.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2745808919.py:7: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2745808919.py:16: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})

# %%
TO_henrico = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("510872")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)
FROM_henrico = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("510872")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_henrico.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_Henrico.xlsx', index=False)
FROM_henrico.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_Henrico.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2095376188.py:7: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2095376188.py:16: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})

# %%
TO_newkent = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("511277")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)
FROM_newkent = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("511277")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_newkent.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_New_Kent.xlsx', index=False)
FROM_newkent.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_New_Kent.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\3591053687.py:7: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\3591053687.py:16: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})

# %%
TO_powhatan = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("511455")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)
FROM_powhatan = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("511455")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_powhatan.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_Powhatan.xlsx', index=False)
FROM_powhatan.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_Powhatan.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2332367988.py:7: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2332367988.py:16: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})

# %%
TO_richmond = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('w_tract.str.startswith("517600")')
    .groupby(['h_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)
FROM_richmond = (
    va_lodes_od
    .assign(w_tract = va_lodes_od['w_geocode'].str.slice(stop = 11),
            h_tract = va_lodes_od['h_geocode'].str.slice(stop = 11))
    .query('h_tract.str.startswith("517600")')
    .groupby(['w_tract'], as_index = False)
    .agg({'S000': sum})
    .rename({'S000': 'workers'}, axis = 1)
)

TO_richmond.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_TO_Richmond.xlsx', index=False)
FROM_richmond.to_excel(r'C:\GreenGIS\Slippy-LODES\outputs\Commute_FROM_Richmond.xlsx', index=False)
# Out:
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2418965455.py:7: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
# C:\Users\egreenwell\AppData\Local\Temp\ipykernel_32260\2418965455.py:16: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg({'S000': sum})
